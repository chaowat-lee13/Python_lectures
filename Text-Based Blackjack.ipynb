# %%
from IPython.display import clear_output

# %%
#Card
#SUIT, RANK, VALUE

import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
face_values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8,
         'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = face_values[rank]
    
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck:
    
    def __init__(self):
        
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                #Create the Card Object
                created_card = Card(suit,rank)
                
                self.all_cards.append(created_card)
    
    def shuffle(self):
        
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        
        return self.all_cards.pop()
    
    def deck_revealed(self):
        for card in self.all_cards:
            print(card)

# %%
class Player:
    
    def __init__(self,name,total):
        
        self.name = name
        self.total = total
        self.all_cards = []
        self.player_score = (0,)
        self.player_decision = " "
        self.bust_con = " "
        self.bet_value = 0
        
    def remove_one(self):
        
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        
        #for a single card object
        self.all_cards.append(new_cards)
        
    def __str__(self):
        
        return f"Player {self.name} has total amount ${self.total}"
            
    def sum_score(self):
        
        if len(self.all_cards) == 2:
        
            for score in range(2):

                if self.all_cards[score].value == 11:
                    game_display()
                    choose_value = input("Please choose your value of Ace (1 or 11): ")
                    clear_output()
                    self.player_score = list(self.player_score)
                    self.player_score = self.player_score + [int(choose_value)]
                    self.player_score = tuple(self.player_score)

                if self.all_cards[score].value != 11:
                    self.player_score = list(self.player_score)
                    self.player_score = self.player_score + [self.all_cards[score].value]
                    self.player_score = tuple(self.player_score)
        
        if len(self.all_cards) > 2:
            
            if self.all_cards[-1].value == 11:
                choose_value = input("Please choose your value of Ace (1 or 11): ")
                self.player_score = list(self.player_score)
                self.player_score = self.player_score + [int(choose_value)]
                self.player_score = tuple(self.player_score)
                
            if self.all_cards[-1].value != 11:
                self.player_score = list(self.player_score)
                self.player_score = self.player_score + [self.all_cards[-1].value]
                self.player_score = tuple(self.player_score)
    
    def decision(self):
        
        decision = " "
        choice = False
        local_bust = " "
        
        while choice == False:
            
            decision = input("Player 1 please make a decision 'HIT' or 'STAND': ").upper()
            self.player_decision = decision
            
            if "HIT" in decision:
                
                player_cardholder = new_deck.deal_one()
                self.add_cards(player_cardholder)
                self.sum_score()
                clear_output()
                if sum(self.player_score) <= 21:
                    game_display()
                    decision = " "
                    self.player_decision = decision
                    
                if sum(self.player_score) > 21:
                    game_display()
                    local_bust = "BUST"
                    self.bust_con = local_bust
                    choice = True
                
            elif "STAND" in decision:
                
                self.player_decision = decision
                choice = True
                print("Dealer's Turn")
                the_dealer.decision()
                
            else:
                
                print("Wrong answer! Try again!")
                choice = False
    
    def betting(self):
        
        bet_amount = 'WRONG'
        bet_choice = False
        
        while bet_choice == False or bet_amount.isdigit() == False:
            
            bet_amount = input("Please choose your betting amount: ")
            
            #Digit Check
            if bet_amount.isdigit() == False:
                print("Sorry, please select betting amount in number")
                
            #Amount check
            if bet_amount.isdigit() == True:
                if int(bet_amount) <= self.total:
                    bet_choice = True
                    self.total = self.total - int(bet_amount)
                    self.bet_value = int(bet_amount)
                    clear_output()
                    
                else:
                    print(f"Sorry, your bet is over the money you have\nYour current balance: {self.total}")
                    bet_choice = False
    
    def choose_amount(self):
        
        insert_money = ' '
        check_condition = False
        
        while insert_money.isdigit() == False or check_condition == False:
            
            insert_money = input("Please put your starting money: ")
            
            #Digit check
            if insert_money.isdigit() == False:
                print("Sorry, unacceptable value!")
                
            if insert_money.isdigit() == True:
                self.total = int(insert_money)
                check_condition = True

# %%
class Dealer:
    
    def __init__(self,name):
        
        self.name = name
        self.all_cards = []
        self.dealer_score = (0,)
        self.bust_con = " "

    def remove_one(self):
        
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        
        self.all_cards.append(new_cards)
    
    def first_card(self):
        
        print(self.all_cards[0])
        print("XXXXXXXXXX")
        
    def sum_score(self):
        
        if len(self.all_cards) == 2:
        
            for score in range(2):
                    self.dealer_score = list(self.dealer_score)
                    self.dealer_score = self.dealer_score + [self.all_cards[score].value]
                    self.dealer_score = tuple(self.dealer_score)
        
        if len(self.all_cards) > 2:
            
            if self.all_cards[-1].value == 11:
                if sum(self.dealer_score) <= 10:
                    self.dealer_score = list(self.dealer_score)
                    self.dealer_score = self.dealer_score + [self.all_cards[-1].value]
                    self.dealer_score = tuple(self.dealer_score)
                        
                elif sum(self.dealer_score) > 10:
                    self.dealer_score = list(self.dealer_score)
                    self.dealer_score = self.dealer_score + [1]
                    self.dealer_score = tuple(self.dealer_score)
                
            if self.all_cards[-1].value != 11:
                self.dealer_score = list(self.dealer_score)
                self.dealer_score = self.dealer_score + [self.all_cards[-1].value]
                self.dealer_score = tuple(self.dealer_score)
    
    def decision(self):
        
        dealer_decision = " "
        dealer_choice = False
        local_bust = " "
        
        while dealer_choice == False:
            
            if sum(self.dealer_score) <= 17:
                dealer_decision = "HIT"
                
                if "HIT" in dealer_decision:
                    dealer_cardholder = new_deck.deal_one()
                    self.add_cards(dealer_cardholder)
                    self.sum_score()
                    clear_output()
                    if sum(self.dealer_score) <= 21:
                        game_display()
                        dealer_decision = " "
                    
                    if sum(self.dealer_score) > 21:
                        game_display()
                        local_bust = "BUST"
                        self.bust_con = local_bust
                        dealer_choice = True
                
            if sum(self.dealer_score) in range(17,22):
                dealer_decision = "STAND"
                dealer_choice = True
                game_display()

# %%
class table:
    def __init__(self,name):
        self.name = name
        self.game_on = False
        self.blackjack_1 = False
        self.blackjack_2 = False
            
    def first_two(self):
        player_cardholder = new_deck.deal_one()
        player_one.add_cards(player_cardholder)

        dealer_cardholder = new_deck.deal_one()
        the_dealer.add_cards(dealer_cardholder)

        player_cardholder = new_deck.deal_one()
        player_one.add_cards(player_cardholder)
        player_one.sum_score()

        dealer_cardholder = new_deck.deal_one()
        the_dealer.add_cards(dealer_cardholder)
        the_dealer.sum_score()

        game_display()        
        
    def win_natural(self):
        
        if player_one.bust_con != "BUST" and the_dealer.bust_con != "BUST":
            
            if player_one.player_score == (0,10,11) or player_one.player_score == (0,11,10):
                
                player_one.total = player_one.total + player_one.bet_value + (player_one.bet_value*1.5)
                player_one.bet_value = 0
                self.blackjack_1 = True
                
            elif the_dealer.dealer_score == (0,10,11) or the_dealer.dealer_score == (0,11,10):
                
                player_one.bet_value = 0
                self.blackjack_2 = True
        
        self.compare_blackjack()   
        
        
    def compare_blackjack(self):
        
        if self.blackjack_1 == True and self.blackjack_2 == False:
            game_display()
            print("Player 1 has BLACKJACK!\nPlayer 1 Win!")
        
        if self.blackjack_1 == False and self.blackjack_2 == True:
            game_display()
            print("The Dealer has BLACKJACK!\nPlayer 1 Lose!")
            
        if self.blackjack_1 == True and self.blackjack_2 == True:
            game_display()
            print("Draw")
        
    def win_condition(self):
        if player_one.bust_con != "BUST" and the_dealer.bust_con != "BUST" and self.blackjack_1 == False and self.blackjack_2 == False:
            
            if sum(player_one.player_score) < sum(the_dealer.dealer_score):
                
                player_one.bet_value = 0
                game_display()
                print("Player 1 Lose!")

            if sum(player_one.player_score) > sum(the_dealer.dealer_score):
                
                player_one.total = player_one.total + player_one.bet_value + player_one.bet_value
                player_one.bet_value = 0
                game_display()
                print("Player 1 Win!")

            if sum(player_one.player_score) == sum(the_dealer.dealer_score):
                
                player_one.total = player_one.total + player_one.bet_value
                player_one.bet_value = 0
                game_display()
                print("DRAW!")
                
        if player_one.bust_con == "BUST":
            
            player_one.bet_value = 0
            game_display()
            print("Player 1 BUST!!\nPlayer 1 Lose!")
            
        if the_dealer.bust_con == "BUST":
           
            player_one.total = player_one.total + player_one.bet_value + player_one.bet_value
            player_one.bet_value = 0
            game_display()
            print("The Dealer BUST!!\nPlayer 1 Win!")
                
            
    def clear_var(self):
        player_cardholder = []
        dealer_cardholder = []
        player_one.player_score = (0,)
        the_dealer.dealer_score = (0,)
        player_one.all_cards = []
        the_dealer.all_cards = []
        player_one.bet_value = 0
        player_one.bust_con = " "
        the_dealer.bust_con = " "
        player_one.player_decision = " "
        self.blackjack_1 = False
        self.blackjack_2 = False        
        
    def gameon_choice(self):
        
        choice = 'wrong'
        
        while choice not in ['Y','N']:
            
            choice = input("Play again? (Y or N) ").upper()
            
            if choice not in ['Y','N']:
                print("Sorry, your choice is unacceptable, please choose Y or N ")
            
            if choice == "Y":
                self.game_on = False
                
            if choice == "N":
                self.game_on = True
                print("GOODBYE!! :):)")
        
    def game_restart(self):
        restart_choice = "wrong"
        
        while restart_choice not in ["Y","N"]:
            
            restart_choice = input("Do you want to restart the game? (Y or N)").upper()
            
            if restart_choice not in ["Y","N"]:
                print("Sorry, your choice is unacceptable, please choose Y or N ")
                
            if restart_choice == "Y":

                new_deck = Deck()
                new_deck.shuffle()

                player_one.choose_amount()
                clear_output()
                table_x.game_on = False
                
            if restart_choice == "N":
                table_x.game_on = True
                print("GOODBYE !! :):)")

# %%
def game_display():
    print("               Blackjack Game")
    print("The Dealer's Hand" + "     |     " + "Player 1's Hand")
    print("---------------------------------------------")
    print("{}".format(the_dealer.all_cards[0]) +"{}".format(alignment)+ " {}".format(player_one.all_cards[0]))
    
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 2 and player_one.player_decision != "STAND":
        print("{}".format(sealed_x) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 2 and player_one.player_decision == "STAND":
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        
    #For adding more cards of Player One
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 3:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        
    if len(the_dealer.all_cards) == 3 and len(player_one.all_cards) == 3:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
    
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 4:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        
    if len(the_dealer.all_cards) == 3 and len(player_one.all_cards) == 4:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        
    if len(the_dealer.all_cards) == 4 and len(player_one.all_cards) == 4:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
    
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 5:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        
    if len(the_dealer.all_cards) == 3 and len(player_one.all_cards) == 5:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[4]))
        
    if len(the_dealer.all_cards) == 4 and len(player_one.all_cards) == 5:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        
    if len(the_dealer.all_cards) == 5 and len(player_one.all_cards) == 5:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
    
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 6:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        
    if len(the_dealer.all_cards) == 3 and len(player_one.all_cards) == 6:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[5]))
        
    if len(the_dealer.all_cards) == 4 and len(player_one.all_cards) == 6:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        
    if len(the_dealer.all_cards) == 5 and len(player_one.all_cards) == 6:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        
    if len(the_dealer.all_cards) == 6 and len(player_one.all_cards) == 6:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 7:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[6]))
        
    if len(the_dealer.all_cards) == 3 and len(player_one.all_cards) == 7:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[5]))
        print("{}".format(space) + "{}".format(alignment) + "  {}".format(player_one.all_cards[6]))
        
    if len(the_dealer.all_cards) == 4 and len(player_one.all_cards) == 7:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[6]))
        
    if len(the_dealer.all_cards) == 5 and len(player_one.all_cards) == 7:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[6]))
        
    if len(the_dealer.all_cards) == 6 and len(player_one.all_cards) == 7:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        print("{}".format(space) + "{}".format(alignment) + "{}".format(player_one.all_cards[6]))
    
    if len(the_dealer.all_cards) == 7 and len(player_one.all_cards) == 7:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        print("{}".format(the_dealer.all_cards[6]) + "{}".format(alignment) + "{}".format(player_one.all_cards[6]))
        
    #For adding more cards of Dealer when player one stand for 2,3,4,5,6
    if len(the_dealer.all_cards) == 3 and len(player_one.all_cards) == 2:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 4 and len(player_one.all_cards) == 2:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 5 and len(player_one.all_cards) == 2:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
    
    if len(the_dealer.all_cards) == 6 and len(player_one.all_cards) == 2:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 7 and len(player_one.all_cards) == 2:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[6]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 4 and len(player_one.all_cards) == 3:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 5 and len(player_one.all_cards) == 3:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 6 and len(player_one.all_cards) == 3:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
    
    if len(the_dealer.all_cards) == 7 and len(player_one.all_cards) == 3:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[6]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 5 and len(player_one.all_cards) == 4:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 6 and len(player_one.all_cards) == 4:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 7 and len(player_one.all_cards) == 4:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[6]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 6 and len(player_one.all_cards) == 5:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 7 and len(player_one.all_cards) == 5:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(space))
        print("{}".format(the_dealer.all_cards[6]) + "{}".format(alignment) + "{}".format(space))
        
    if len(the_dealer.all_cards) == 7 and len(player_one.all_cards) == 6:
        print("{}".format(the_dealer.all_cards[1]) + "{}".format(alignment) + "{}".format(player_one.all_cards[1]))
        print("{}".format(the_dealer.all_cards[2]) + "{}".format(alignment) + "{}".format(player_one.all_cards[2]))
        print("{}".format(the_dealer.all_cards[3]) + "{}".format(alignment) + "{}".format(player_one.all_cards[3]))
        print("{}".format(the_dealer.all_cards[4]) + "{}".format(alignment) + "{}".format(player_one.all_cards[4]))
        print("{}".format(the_dealer.all_cards[5]) + "{}".format(alignment) + "{}".format(player_one.all_cards[5]))
        print("{}".format(the_dealer.all_cards[6]) + "{}".format(alignment) + "{}".format(space))
    
    
    print("---------------------------------------------")
    if len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 2 and player_one.player_decision != "STAND":
        
        print(f"The Dealer score: XX  |     Player 1 score: {sum(player_one.player_score)}")
        
    elif len(the_dealer.all_cards) == 2 and len(player_one.all_cards) == 2 and player_one.player_decision == "STAND":
        
        print(f"The Dealer score: {sum(the_dealer.dealer_score)}  |     Player One score: {sum(player_one.player_score)}")
        
    else:
        
        print(f"The Dealer score: {sum(the_dealer.dealer_score)}  |     Player One score: {sum(player_one.player_score)}")
    print("---------------------------------------------")
    
    print(f"Your current amount: {player_one.total}     Your current bet amount: {player_one.bet_value}")

# %%
#Game_setup
player_one = Player("One",0)
the_dealer = Dealer("Autobot")
table_x = table("CASINO")
player_cardholder = []
dealer_cardholder = []
sealed_x = "XXXXXXXXXXXXXXX"
space = "               "
alignment ="             "

new_deck = Deck()
new_deck.shuffle()
table_x.game_on = False

player_one.choose_amount()
clear_output()
while table_x.game_on == False:
    
    player_one.betting()
    table_x.first_two()
    player_one.decision()
    table_x.win_natural()
    table_x.win_condition()
    table_x.clear_var()
    
    if player_one.total > 0:
        if len(new_deck.all_cards) > 8:
            table_x.gameon_choice()
        else:
            new_deck = Deck()
            new_deck.shuffle()
    else:
        print("You're out of money")
        table_x.game_restart()
# Out:
#                Blackjack Game
# The Dealer's Hand     |     Player 1's Hand
# ---------------------------------------------
# Three of Clubs              Eight of Diamonds
# Four of Spades             Six of Hearts
# Ten of Diamonds
# ---------------------------------------------
# The Dealer score: 17  |     Player One score: 14
# ---------------------------------------------
# Your current amount: 3500     Your current bet amount: 1500
#                Blackjack Game
# The Dealer's Hand     |     Player 1's Hand
# ---------------------------------------------
# Three of Clubs              Eight of Diamonds
# Four of Spades             Six of Hearts
# Ten of Diamonds
# ---------------------------------------------
# The Dealer score: 17  |     Player One score: 14
# ---------------------------------------------
# Your current amount: 3500     Your current bet amount: 1500
#                Blackjack Game
# The Dealer's Hand     |     Player 1's Hand
# ...
