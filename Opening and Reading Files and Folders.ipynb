# %%
pwd
# Out:
# 'C:\\Users\\chaow\\Desktop\\Python Learning Docs\\Example'

# %%
f = open('pratice.txt','w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\chaow\\Desktop\\Python Learning Docs\\Example'

# %%
os.listdir('C:\\Users')
# Out:
# ['All Users',
#  'chaow',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'postgres',
#  'Public']

# %%
import shutil

# %%
shutil.move('pratice.txt','C:\\Users\\chaow')
# Out:
# 'C:\\Users\\chaow\\pratice.txt'

# %%
os.listdir('C:\\Users\\chaow')
# Out:
# ['.android',
#  '.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.pylint.d',
#  '.python_history',
#  '3D Objects',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Creative Cloud Files',
#  'debug.log',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'pratice.txt',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'source',
#  'Start Menu',
#  'Templates',
#  'Videos']

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'args and kwargs.ipynb',
#  'Basic Functions.ipynb',
#  'Booleans.ipynb',
#  'Collection Module.ipynb',
#  'Comparison Operators & Chaining.ipynb',
#  'Decorators.ipynb',
#  'Dictionaries.ipynb',
#  'Errors and Exception Handling.ipynb',
#  'example1.py',
#  'For loops.ipynb',
#  'Formatting with the .format() method.ipynb',
#  'Functions and Tuple Unpacking.ipynb',
#  'Functions with Logic.ipynb',
#  'Generators.ipynb',
#  'If Elif and Else statement.ipynb',
#  'Interactions between Functions.ipynb',
#  'IO with Basic files.ipynb',
#  'Lambda Expressions Map and Filter.ipynb',
#  'List comprehensions.ipynb',
#  'Lists.ipynb',
#  'Methods.ipynb',
#  'Milestone-2 Warm up.ipynb',
#  'myfile.txt',
#  'my_new_file.txt',
#  'Nested Statements and Scope.ipynb',
#  'Object Oriented Programming.ipynb',
#  'Opening and Reading Files and Folders.ipynb',
#  'sdwqedsfge,txt',
#  'sdwqedsfge.txt',
#  'Sets.ipynb',
#  'String Properties and Methods Immutability.ipynb',
# ...

# %%
 shutil.move('C:\\Users\\chaow\\pratice.txt',os.getcwd())
# Out:
# 'C:\\Users\\chaow\\Desktop\\Python Learning Docs\\Example\\pratice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'args and kwargs.ipynb',
#  'Basic Functions.ipynb',
#  'Booleans.ipynb',
#  'Collection Module.ipynb',
#  'Comparison Operators & Chaining.ipynb',
#  'Decorators.ipynb',
#  'Dictionaries.ipynb',
#  'Errors and Exception Handling.ipynb',
#  'example1.py',
#  'For loops.ipynb',
#  'Formatting with the .format() method.ipynb',
#  'Functions and Tuple Unpacking.ipynb',
#  'Functions with Logic.ipynb',
#  'Generators.ipynb',
#  'If Elif and Else statement.ipynb',
#  'Interactions between Functions.ipynb',
#  'IO with Basic files.ipynb',
#  'Lambda Expressions Map and Filter.ipynb',
#  'List comprehensions.ipynb',
#  'Lists.ipynb',
#  'Methods.ipynb',
#  'Milestone-2 Warm up.ipynb',
#  'myfile.txt',
#  'my_new_file.txt',
#  'Nested Statements and Scope.ipynb',
#  'Object Oriented Programming.ipynb',
#  'Opening and Reading Files and Folders.ipynb',
#  'pratice.txt',
#  'sdwqedsfge,txt',
#  'sdwqedsfge.txt',
#  'Sets.ipynb',
# ...

# %%
send2trash.send2trash('pratice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'args and kwargs.ipynb',
#  'Basic Functions.ipynb',
#  'Booleans.ipynb',
#  'Collection Module.ipynb',
#  'Comparison Operators & Chaining.ipynb',
#  'Decorators.ipynb',
#  'Dictionaries.ipynb',
#  'Errors and Exception Handling.ipynb',
#  'example1.py',
#  'For loops.ipynb',
#  'Formatting with the .format() method.ipynb',
#  'Functions and Tuple Unpacking.ipynb',
#  'Functions with Logic.ipynb',
#  'Generators.ipynb',
#  'If Elif and Else statement.ipynb',
#  'Interactions between Functions.ipynb',
#  'IO with Basic files.ipynb',
#  'Lambda Expressions Map and Filter.ipynb',
#  'List comprehensions.ipynb',
#  'Lists.ipynb',
#  'Methods.ipynb',
#  'Milestone-2 Warm up.ipynb',
#  'myfile.txt',
#  'my_new_file.txt',
#  'Nested Statements and Scope.ipynb',
#  'Object Oriented Programming.ipynb',
#  'Opening and Reading Files and Folders.ipynb',
#  'sdwqedsfge,txt',
#  'sdwqedsfge.txt',
#  'Sets.ipynb',
#  'String Properties and Methods Immutability.ipynb',
# ...

# %%
os. getcwd()
# Out:
# 'C:\\Users\\chaow\\Desktop\\Python Learning Docs\\Example'

# %%
file_path = 'C:\\Users\\chaow\\Desktop\\Python Learning Docs'

# %%
for folder, sub_folders, files in os.walk(file_path):
    
    print(f"Currently looking at {folder}")
    print("\n")
    print("The subfolders are: ")
    for sub_fold in sub_folders:
        print(f"Subfolders: {sub_fold}")
        
    print("\n")
    print("the files are: ")
    for f in files:
        print(f"file: {f}")
    print("\n")
# Out:
# Currently looking at C:\Users\chaow\Desktop\Python Learning Docs
#
#
# The subfolders are:
# Subfolders: Assessment
# Subfolders: Docs
# Subfolders: Example
# Subfolders: Python Modules Example
#
#
# the files are:
#
#
# Currently looking at C:\Users\chaow\Desktop\Python Learning Docs\Assessment
#
#
# The subfolders are:
# Subfolders: Complete-Python-3-Bootcamp-master
#
#
# the files are:
#
#
# Currently looking at C:\Users\chaow\Desktop\Python Learning Docs\Assessment\Complete-Python-3-Bootcamp-master
#
#
# The subfolders are:
# Subfolders: 00-Python Object and Data Structure Basics
# Subfolders: 01-Python Comparison Operators
# Subfolders: 02-Python Statements
# Subfolders: 03-Methods and Functions
# Subfolders: 04-Milestone Project - 1
# Subfolders: 05-Object Oriented Programming
# Subfolders: 06-Modules and Packages
# Subfolders: 07-Errors and Exception Handling
# Subfolders: 08-Milestone Project - 2
# Subfolders: 09-Built-in Functions
# Subfolders: 10-Python Decorators
# ...
