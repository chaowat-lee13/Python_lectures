# %%
player_1 = 'X'
player_2 = 'O'
row_1 = [' ',' ',' ']
row_2 = [' ',' ',' ']
row_3 = [' ',' ',' ']
acceptable_range = [1,2,3,4,5,6,7,8,9]
check_list = []

# %%
from IPython.display import clear_output

def game_display(row_1,row_2,row_3):
    
    clear_output()
    print("Here is the Current game play")
    print("     |     |    ")
    print(f"  {row_1[0]}  |  {row_1[1]}  |  {row_1[2]} ")
    print("_____|_____|_____")
    
    print("     |     |    ")
    print(f"  {row_2[0]}  |  {row_2[1]}  |  {row_2[2]} ")
    print("_____|_____|_____")
    
    print("     |     |    ")
    print(f"  {row_3[0]}  |  {row_3[1]}  |  {row_3[2]} ")
    print("     |     |    ")

# %%
def renew_var(row_1,row_2,row_3,check_list):
    row_1[0] = ' '
    row_1[1] = ' '
    row_1[2] = ' '
    row_2[0] = ' '
    row_2[1] = ' '
    row_2[2] = ' '
    row_3[0] = ' '
    row_3[1] = ' '
    row_3[2] = ' '
    check_list = []

# %%
def user_1_choice(user_2_choice,acceptable_range,win_condition_1,game_display,check_list):
    
    #initial
    choice_1 = 'WRONG'
    
    within_range1 = False
    
    #Two conditions to check
    #Digit or within_range1==False
    
    while choice_1.isdigit() == False or within_range1 == False:
        
        choice_1 = input("Player 1 Please enter a number(1-9): ")
        
        #Digit Check
        if choice_1.isdigit() == False:
            print("Sorry, please select a number (1-9)")
            
        #Range Check
        if choice_1.isdigit() == True:
            if int(choice_1) in acceptable_range:
                within_range1 = True
                if int(choice_1) == 1:
                    if row_3[0].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_3[0] = player_1
                        check_list = check_list + [1]
                        
                elif int(choice_1) == 2:
                    if row_3[1].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_3[1] = player_1
                        check_list = check_list + [2]
                
                elif int(choice_1) == 3:
                    if row_3[2].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_3[2] = player_1
                        check_list = check_list + [3]
                
                elif int(choice_1) == 4:
                    if row_2[0].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_2[0] = player_1
                        check_list = check_list + [4]
                
                elif int(choice_1) == 5:
                    if row_2[1].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_2[1] = player_1
                        check_list = check_list + [5]
                        
                elif int(choice_1) == 6:
                    if row_2[2].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_2[2] = player_1
                        check_list = check_list + [6]
                
                elif int(choice_1) == 7:
                    if row_1[0].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_1[0] = player_1
                        check_list = check_list + [7]
                
                elif int(choice_1) == 8:
                    if row_1[1].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_1[1] = player_1
                        check_list = check_list + [8]
                        
                elif int(choice_1) == 9:
                    if row_1[2].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range1 = False
                    else:    
                        row_1[2] = player_1
                        check_list = check_list + [9]

            else:
                print("Sorry, you are out of acceptable range")
                within_range = False
                
    game_display(row_1,row_2,row_3)
    win_condition_1(row_1,row_2,row_3,user_2_choice,gameon_choice,check_list)

# %%
def user_2_choice(user_1_choice,acceptable_range,win_condition_2,game_display,check_list):
    
    #initial
    choice_2 = 'WRONG'
    
    within_range2 = False
    
    #Two conditions to check
    #Digit or within_range2==False
    
    while choice_2.isdigit() == False or within_range2 == False:
        
        choice_2 = input("Player 2 Please enter a number(1-9): ")
        
        #Digit Check
        if choice_2.isdigit() == False:
            print("Sorry, please select a number (1-9)")
            
        #Range Check
        if choice_2.isdigit() == True:
            if int(choice_2) in acceptable_range:
                within_range2 = True
                if int(choice_2) == 1:
                    if row_3[0].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_3[0] = player_2
                        check_list = check_list + [1]
                        
                elif int(choice_2) == 2:
                    if row_3[1].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_3[1] = player_2
                        check_list = check_list + [2]
                
                elif int(choice_2) == 3:
                    if row_3[2].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_3[2] = player_2
                        check_list = check_list + [3]
                
                elif int(choice_2) == 4:
                    if row_2[0].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_2[0] = player_2
                        check_list = check_list + [4]
                
                elif int(choice_2) == 5:
                    if row_2[1].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_2[1] = player_2
                        check_list = check_list + [5]
                        
                elif int(choice_2) == 6:
                    if row_2[2].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_2[2] = player_2
                        check_list = check_list + [6]
                
                elif int(choice_2) == 7:
                    if row_1[0].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_1[0] = player_2
                        check_list = check_list + [7]
                
                elif int(choice_2) == 8:
                    if row_1[1].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_1[1] = player_2
                        check_list = check_list + [8]
                        
                elif int(choice_2) == 9:
                    if row_1[2].isspace() == False:
                        print("This position is already selected, Please select a new one")
                        within_range2 = False
                    else:    
                        row_1[2] = player_2
                        check_list = check_list + [9]

            else:
                print("Sorry, you are out of acceptable range")
                within_range = False
    
    game_display(row_1,row_2,row_3)
    win_condition_2(row_1,row_2,row_3,user_1_choice,gameon_choice,check_list)

# %%
def win_condition_1(row_1,row_2,row_3,user_2_choice,gameon_choice,check_list):
    
    #Initial
    winner = False
    
    if winner == False:
        #FOR X
        if row_1 == ['X','X','X']:
            print("Player 1 You are Winner!!")
            winner = True
        elif row_2 == ['X','X','X']:
            print("Player 1 You are Winner!!")
            winner = True
        elif row_3 == ['X','X','X']:
            print("Player 1 You are Winner!!")
            winner = True
        elif row_1[0] == 'X' and row_2[0] == 'X' and row_3[0] == 'X':
            print("Player 1 You are Winner!!")
            winner = True
        elif row_1[1] == 'X' and row_2[1] == 'X' and row_3[1] == 'X':
            print("Player 1 You are Winner!!")
            winner = True
        elif row_1[2] == 'X' and row_2[2] == 'X' and row_3[2] == 'X':
            print("Player 1 You are Winner!!")
            winner = True
        elif row_1[0] == 'X' and row_2[1] == 'X' and row_3[2] == 'X':
            print("Player 1 You are Winner!!")
            winner = True
        elif row_1[2] == 'X' and row_2[1] == 'X' and row_3[0] == 'X':
            print("Player 1 You are Winner!!")
            winner = True
        else:
            winner = False                
            if winner == False and sorted(check_list) == [1,2,3,4,5,6,7,8,9]:
                print("Draw!!")
                gameon_choice(play_game,clear_output)
                
            elif winner == False:
                user_2_choice(user_1_choice,acceptable_range,win_condition_2,game_display,check_list)
    
    if winner == True:
        gameon_choice(play_game,clear_output)

# %%
def win_condition_2(row_1,row_2,row_3,user_1_choice,gameon_choice,check_list):
    
    #Initial
    winner = False    
    
    if winner == False:
        #FOR O
        if row_1 == ['O','O','O']:
            print("Player 2 You are Winner!!")
            winner = True
        elif row_2 == ['O','O','O']:
            print("Player 2 You are Winner!!")
            winner = True
        elif row_3 == ['O','O','O']:
            print("Player 2 You are Winner!!")
            winner = True
        elif row_1[0] == 'O' and row_2[0] == 'O' and row_3[0] == 'O':
            print("Player 2 You are Winner!!")
            winner = True
        elif row_1[1] == 'O' and row_2[1] == 'O' and row_3[1] == 'O':
            print("Player 2 You are Winner!!")
            winner = True
        elif row_1[2] == 'O' and row_2[2] == 'O' and row_3[2] == 'O':
            print("Player 2 You are Winner!!")
            winner = True
        elif row_1[0] == 'O' and row_2[1] == 'O' and row_3[2] == 'O':
            print("Player 2 You are Winner!!")
            winner = True
        elif row_1[2] == 'O' and row_2[1] == 'O' and row_3[0] == 'O':
            print("Player 2 You are Winner!!")
            winner = True
        else:
            winner = False
            if winner == False and sorted(check_list) == [1,2,3,4,5,6,7,8,9]:
                print("Draw!!")
                gameon_choice(play_game,clear_output)
                
            elif winner == False:
                user_1_choice(user_2_choice,acceptable_range,win_condition_1,game_display,check_list)
    
    
    if winner == True:
        gameon_choice(play_game,clear_output)

# %%
def gameon_choice(play_game,clear_output):
    
    choice = 'wrong'
    
    while choice not in ['Y','N']:
        
        choice = input("Play again? (Y or N) ").upper()
        
        if choice not in ['Y','N']:
            print("Sorry, your choice is unacceptable, please choose Y or N ")
    
    if choice == 'Y':
        play_game(user_1_choice,renew_var)
    else:
        clear_output()
        print("GOODBYE!! :):)")

# %%
def play_game(user_1_choice,renew_var):
    print("Player 1 is 'X'\nPlayer 2 is 'O'")
    renew_var(row_1,row_2,row_3,check_list)
    user_1_choice(user_2_choice,acceptable_range,win_condition_1,game_display,check_list)

# %%
play_game(user_1_choice,renew_var)
# Out:
# GOODBYE!! :):)
